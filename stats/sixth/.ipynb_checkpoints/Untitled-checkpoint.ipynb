# %% [markdown]
# # Курс "Методы современной прикладной статистики"
# # 3 курс ФПМИ МФТИ, весна 2022
# ## Домашнее задание 6. Критерии однородности.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps
import scipy.special as spss
import seaborn as sns
import pandas as pd
sns.set(style='darkgrid', font_scale=1.4)
# %matplotlib inline
# %config InlineBackend.figure_format="retina"  # only for retina display

# %%
import warnings
warnings.filterwarnings('ignore')
from scipy.optimize import minimize, fmin

# %%
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multitest import fdrcorrection
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ### Задача 1

# %% [markdown]
# ### Задача 2

# %% [markdown]
# ![Screenshot%20from%202022-04-03%2018-15-47.png](attachment:Screenshot%20from%202022-04-03%2018-15-47.png)

# %% [markdown]
# ![Screenshot%20from%202022-04-03%2018-16-22.png](attachment:Screenshot%20from%202022-04-03%2018-16-22.png)

# %% [markdown]
# Напишем функцию для подсчета статистики Розенблатта и с помощью моделирования найдем критические значения для $\alpha = 0.01, 0.05, 0.1$. Для нашей же задачи стандартно зафиксируем $\alpha = 0.05$.

# %%
num_samples = 10000
sz_first, sz_second = 200, 250
data = np.load("hw6t2.npy").T
data.shape
# Out:
# (2, 100)

# %%
def calc_Rosenblatt_stat(x, y):
    sz_first, sz_second = x.shape[0], y.shape[0]
    divider = 1 / (sz_first + sz_second)
    multipier = sz_first * sz_second
    mod = []
    for el in x:
        mod.append(el)
    for el in y:
        mod.append(el)
    mod = np.array(mod)
    ranks = np.argsort(mod).argsort()
    first_ranks = sorted(ranks[:sz_first])
    second_ranks = sorted(ranks[sz_first:])
    z = divider * (1 / 6 + np.sum(np.power(first_ranks - np.arange(sz_first), 2)) / sz_second + 
                       np.sum(np.power(second_ranks - np.arange(sz_second), 2)) / sz_first)
    return z  - (2.0 / 3.0) * multipier * divider

# %%
def calc_critical_values_for_Rosenblatt(num_samples, sz_first, sz_second, alphas):
    first_batch = sps.norm().rvs((num_samples, sz_first))
    second_batch = sps.norm().rvs((num_samples, sz_second))
    stats_vals = np.array([])
    for x, y in zip(first_batch, second_batch):
        stats_vals = np.append(stats_vals, calc_Rosenblatt_stat(x, y))
    stats_vals = sorted(stats_vals)
    return [stats_vals[int((1 - alpha) * len(stats_vals))] for alpha in alphas]

# %%
critical = calc_critical_values_for_Rosenblatt(num_samples, sz_first, sz_second, [0.01, 0.05, 0.1])
critical
# Out:
# [0.7613674074074055, 0.45998740740741084, 0.34806296296298456]

# %% [markdown]
# Кажется, что очень неплохо приблизились к табличным значениям, значит все сделано верно. Теперь уже взлянем на данные из нашей задачи.

# %%
plt.figure(figsize = (16, 9))
plt.hist(data)
plt.hist(data[0], color = 'red', alpha = 0.5)
plt.hist(data[1], color = 'blue', alpha = 0.5)
plt.show()

# %% [markdown]
# Кажется, что распредления все же немного отличаются. Проверим на уровне значимости 0.05.

# %%
stat_val = calc_Rosenblatt_stat(data[0], data[1]) 
print(f"Значение статистики -- {stat_val}")
if stat_val < critical[1]:
    print(f"Гипотеза об однородности на уровне значимости 0.05 не отвергается")
else:
    print(f"Гипотеза об однородности на уровне значимости 0.05 отвергается")
# Out:
# Значение статистики -- 0.5781000000000063
# Гипотеза об однородности на уровне значимости 0.05 отвергается

# %% [markdown]
# ### Задача 3

# %%
data = pd.read_csv('h6t3.txt', sep="\t", header=None)
data.columns = ["first", "second"]

# %%
data.head()
# Out:
#     first second
# 0  Before  After
# 1   80.50  82.20
# 2   84.90  85.60
# 3   81.50  81.40
# 4   82.60  81.90

# %%
data = data[data['first'] != "Before"]
data.head()
# Out:
#    first second
# 1  80.50  82.20
# 2  84.90  85.60
# 3  81.50  81.40
# 4  82.60  81.90
# 5  79.90  76.40

# %%
first = data["first"].astype(float).to_numpy()
second = data["second"].astype(float).to_numpy()

# %%
plt.figure(figsize = (16, 9))
plt.hist(first, color = 'red', alpha = 0.3)
plt.hist(second, color = 'blue', alpha = 0.3)
plt.show()

# %% [markdown]
# Есть подозрение на нормальность, хотя со второй выборкой кажется может не получиться. Поэтому у нас есть основных варианта действия: проверить выборки на нормальность и применить парный t-тест на проверку равенств средних далее, либо использовать какой-нибудь двувыборочный критерий связанный с рангами и знаками. Мы поступим следующим образом: запустим процедуру множественной проверки гипотез, где проверим нормальность и будем использовать парный t-тест, а также еще воспользуемся двувыборочным критерием знаков. Чтобы контролировать FWER воспользуемся методом Холма.

# %%
p_vals = [sps.shapiro(first)[1],sps.shapiro(second)[1], 
          sps.ttest_rel(first, second, alternative="less")[1],sps.binom_test(sum(second > first), len(second),  p=0.5) / 2.0]
p_vals
# Out:
# [0.5579800605773926,
#  0.20574407279491425,
#  0.017511298781094416,
#  0.132465448230505]

# %%
ans = multipletests(np.array(p_vals), alpha = 0.05, method = "holm")[0]
ans
# Out:
# array([False, False, False, False])

# %% [markdown]
# Как мы можем видеть, ни одна из гипотез не отвергается. Это означает, что гипотеза о том, что терапия оказалась не эффективной, не отвергается.

# %% [markdown]
# ###  Задача 4

# %%
al = 0.1
data = np.load("hw6t4.npy").T
data.shape
# Out:
# (2, 100)

# %%
plt.figure(figsize = (16, 9))
plt.hist(data[0], color = 'red', alpha = 0.3)
plt.hist(data[1], color = 'blue', alpha = 0.3)
plt.show()

# %% [markdown]
# Как сказано в условии, будем контролировать FDR на уровне 0.1. Для начала посмотрим, что нам скажут критерии нормальности:

# %%
sps.shapiro(data[0]), sps.shapiro(data[1])
# Out:
# (ShapiroResult(statistic=0.9765814542770386, pvalue=0.07177740335464478),
#  ShapiroResult(statistic=0.9240764379501343, pvalue=2.3313081328524277e-05))

# %% [markdown]
# Так мы видим, pvalue у второй выборки очень маленький, и в любой процедуре множественной проверки гипотез гипотеза о нормальности второй выборки отвергнется. Поэтому, будем считать, что данные не являются нормальными. Теперь проверим независимость с помощью коэффициентов корреляции Спирмена. Если будет подозрение на то, что гипотезу о независимости можно не отвергать, то будет вооможность использовать больше критериев для проверки отсутствия эффекта.

# %%
sps.spearmanr(data[0], data[1])
# Out:
# SpearmanrResult(correlation=0.07398739873987398, pvalue=0.4644277221300104)

# %% [markdown]
# Теперь, посмотрим еще на general qq-plot. Если точки графика будут лежать приблизительно на одной линии, можно будет предполагать, что распределения выборок отличаются только параметром сдвига и маштаба.

# %%
d = {'first':data[0], 'second': data[1]}
frame = pd.DataFrame(d)

# %%
import seaborn as sns
from seaborn_qqplot import pplot

# %% [markdown]
# pplot(frame, x="first", y="second", kind='qq', height=4, aspect=2)

# %% [markdown]
# Кажется, что действительно основная масса точек лежит на одной линии. Но теперь еще заметим, что на самом деле данные первой и второй выборки согласно гистограмме приблизительно равностепенно раскиданы. А значит, есть смысл рассмотреть гипотезу о равенстве дисперсий, что откроет нам дорогу к двум очень хорошим критериям -- двувыборочному t-тесту и критерию Манна-Уитни.
#
# Собственно запустим процедуру множественной проверки гипотез с контролем FDR на уровне  0.1 c помощью метода Бенджамини-Иекутелли, где гипотезы будут следующими: гипотеза о независимости, гипотеза о равенстве дисперсий выборок, двувыборочный t-тест и тест Манна-Уитни. Если все гипотезы не отвергнуться, то следовательно и гипотезу об отсутсвии эффекта отклонять не нужно.

# %%
from scipy.stats import f
def F_test(x, y):
    x = np.array(x)
    y = np.array(y)
    df1 = len(x) - 1
    df2 = len(y) - 1
    F_stat = np.var(x, ddof=1)/np.var(y, ddof=1)
    pv = 2*np.min([f.cdf(F_stat, df1, df2), 1 - f.cdf(F_stat, df1, df2)])
    return (F_stat, pv)

# %%
p_vals =  [sps.spearmanr(data[0], data[1])[1], F_test(data[0], data[1])[1],
          sps.ttest_ind(data[0], data[1], equal_var=True)[1], sps.mannwhitneyu(data[0], data[1])[1]]
p_vals
# Out:
# [0.4644277221300104,
#  0.34696485358418383,
#  0.493808423039501,
#  0.07592211987792999]

# %%
multipletests(np.array(p_vals), alpha = al, method = "fdr_by")[0]
# Out:
# array([False, False, False, False])

# %% [markdown]
# Таким образом, гипотеза об отсутсвии эффекта не отклоняется.

# %% [markdown]
# ### Задача 5

# %%
num_samples = 10000
sizes = [10, 20, 50, 100, 500, 10000]
alphas = [0.01, 0.05, 0.1]

# %%
def calc_critical_vals(num_samples, sizes, alphas, distr):
    first = distr.rvs((num_samples, sizes[-1]))
    second = distr.rvs((num_samples, sizes[-1]))
    stats_vals = [[] for sz in sizes]
    for x, y in zip(first, second):
        for ind, sz in enumerate(sizes):
            stats_vals[ind].append(sps.ttest_ind(x[:sz], y[:sz])[0])
    result = dict()
    for ind, sz in enumerate(sizes):
        result[sz] = dict()
        for alpha in alphas:
            result[sz][alpha] = (np.round(np.quantile(stats_vals[ind], alpha / 2.0), 3),
                                 np.round(np.quantile(stats_vals[ind], 1.0 - alpha / 2.0), 3))
    return result

# %%
def write_results(results):
    for sz in sizes:
        for al in alphas:
            print("------------------------------------------------------------------------------------")
            print(f"Критические значения для статистики при n={sz} и a = {al}" +
                 f", полученные моделированием, равны {results[sz][al][0]} и {results[sz][al][1]}")
            print(f"Критические значения распределения Стьюдента -- {sps.t(2*sz - 2).ppf(al / 2)} и {sps.t(2*sz - 2).ppf(1- al/ 2)}")
            print("Критические значения стандартного нормального распределения" + 
                  f" -- {sps.norm().ppf(al / 2)} и {sps.norm().ppf(1- al / 2)}")
            print("------------------------------------------------------------------------------------")
        print("////////////////////////////////////////////////////////////////////////////////////")
        print("////////////////////////////////////////////////////////////////////////////////////")

# %%
results_t = calc_critical_vals(num_samples, sizes, alphas, sps.t(10))
write_results(results_t)
# Out:
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.01, полученные моделированием, равны -2.83 и 2.876
# Критические значения распределения Стьюдента -- -2.8784404727135864 и 2.878440472713585
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.05, полученные моделированием, равны -2.106 и 2.09
# Критические значения распределения Стьюдента -- -2.10092204024096 и 2.10092204024096
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.1, полученные моделированием, равны -1.748 и 1.706
# Критические значения распределения Стьюдента -- -1.734063606617536 и 1.7340636066175354
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.01, полученные моделированием, равны -2.678 и 2.61
# Критические значения распределения Стьюдента -- -2.7115576019130625 и 2.7115576019130625
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.05, полученные моделированием, равны -2.029 и 2.021
# Критические значения распределения Стьюдента -- -2.0243941645751367 и 2.024394164575136
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.1, полученные моделированием, равны -1.711 и 1.687
# Критические значения распределения Стьюдента -- -1.6859544576438146 и 1.685954457643814
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.01, полученные моделированием, равны -2.622 и 2.661
# Критические значения распределения Стьюдента -- -2.6269310948140245 и 2.626931094814024
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.05, полученные моделированием, равны -2.011 и 1.951
# Критические значения распределения Стьюдента -- -1.9844674544266925 и 1.984467454426692
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.1, полученные моделированием, равны -1.683 и 1.637
# Критические значения распределения Стьюдента -- -1.6605512170440575 и 1.6605512170440568
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.01, полученные моделированием, равны -2.591 и 2.618
# Критические значения распределения Стьюдента -- -2.600887277962623 и 2.6008872779626224
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.05, полученные моделированием, равны -1.934 и 1.931
# Критические значения распределения Стьюдента -- -1.972017477833896 и 1.9720174778338955
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.1, полученные моделированием, равны -1.636 и 1.617
# Критические значения распределения Стьюдента -- -1.6525857836172082 и 1.6525857836172075
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.01, полученные моделированием, равны -2.506 и 2.44
# Критические значения распределения Стьюдента -- -2.5807645863853454 и 2.580764586385345
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.05, полученные моделированием, равны -1.923 и 1.957
# Критические значения распределения Стьюдента -- -1.962343846216334 и 1.9623438462163336
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.1, полученные моделированием, равны -1.63 и 1.626
# Критические значения распределения Стьюдента -- -1.6463818766348761 и 1.6463818766348755
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.01, полученные моделированием, равны -2.531 и 2.586
# Критические значения распределения Стьюдента -- -2.57607517760687 и 2.5760751776068695
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.05, полученные моделированием, равны -1.922 и 1.954
# Критические значения распределения Стьюдента -- -1.960082617022089 и 1.9600826170220886
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.1, полученные моделированием, равны -1.625 и 1.661
# Критические значения распределения Стьюдента -- -1.6449298265798 и 1.6449298265797994
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Как можно заметить, для выборок малого размера критические значения лучше приближаются квантилями распределения Стьюдента. Это связано скорее всего с тем, что распределение Стьюдента с 10 степенями свободы уже достаточно сильно похоже на нормальное распределение, а для нормального распределения двустороний t-test -- точный критерий, а не асимптотический!!!
#
# Проверим, что если мы будем моделировать распредление t-статистики с помощью какого-либо другого распределения, которое меньше похоже на нормальное, то уже будет непонятно, квантили какого распределения лучше описывают критические значения. В качестве примера возьмем стандартное экспоненциальное распределение.

# %%
results_exp = calc_critical_vals(num_samples, sizes, alphas, sps.expon())
write_results(results_exp)
# Out:
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.01, полученные моделированием, равны -2.747 и 2.767
# Критические значения распределения Стьюдента -- -2.8784404727135864 и 2.878440472713585
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.05, полученные моделированием, равны -2.066 и 2.05
# Критические значения распределения Стьюдента -- -2.10092204024096 и 2.10092204024096
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.1, полученные моделированием, равны -1.718 и 1.713
# Критические значения распределения Стьюдента -- -1.734063606617536 и 1.7340636066175354
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.01, полученные моделированием, равны -2.645 и 2.626
# Критические значения распределения Стьюдента -- -2.7115576019130625 и 2.7115576019130625
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.05, полученные моделированием, равны -1.999 и 1.979
# Критические значения распределения Стьюдента -- -2.0243941645751367 и 2.024394164575136
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.1, полученные моделированием, равны -1.692 и 1.665
# Критические значения распределения Стьюдента -- -1.6859544576438146 и 1.685954457643814
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.01, полученные моделированием, равны -2.593 и 2.574
# Критические значения распределения Стьюдента -- -2.6269310948140245 и 2.626931094814024
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.05, полученные моделированием, равны -1.978 и 1.964
# Критические значения распределения Стьюдента -- -1.9844674544266925 и 1.984467454426692
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.1, полученные моделированием, равны -1.654 и 1.671
# Критические значения распределения Стьюдента -- -1.6605512170440575 и 1.6605512170440568
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.01, полученные моделированием, равны -2.581 и 2.541
# Критические значения распределения Стьюдента -- -2.600887277962623 и 2.6008872779626224
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.05, полученные моделированием, равны -1.986 и 1.956
# Критические значения распределения Стьюдента -- -1.972017477833896 и 1.9720174778338955
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.1, полученные моделированием, равны -1.634 и 1.635
# Критические значения распределения Стьюдента -- -1.6525857836172082 и 1.6525857836172075
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.01, полученные моделированием, равны -2.568 и 2.611
# Критические значения распределения Стьюдента -- -2.5807645863853454 и 2.580764586385345
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.05, полученные моделированием, равны -1.975 и 1.961
# Критические значения распределения Стьюдента -- -1.962343846216334 и 1.9623438462163336
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.1, полученные моделированием, равны -1.667 и 1.643
# Критические значения распределения Стьюдента -- -1.6463818766348761 и 1.6463818766348755
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.01, полученные моделированием, равны -2.63 и 2.553
# Критические значения распределения Стьюдента -- -2.57607517760687 и 2.5760751776068695
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.05, полученные моделированием, равны -1.952 и 1.909
# Критические значения распределения Стьюдента -- -1.960082617022089 и 1.9600826170220886
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.1, полученные моделированием, равны -1.654 и 1.612
# Критические значения распределения Стьюдента -- -1.6449298265798 и 1.6449298265797994
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Как видим, здесь уже непонятно, какие квантили лучше описывают критические значения.
#
# Осталось проверить, что если брать распределение без первых двух моментов, будет все не очень. Рассмотрим распределение Коши.

# %%
results_cau = calc_critical_vals(num_samples, sizes, alphas, sps.cauchy())
write_results(results_cau)
# Out:
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.01, полученные моделированием, равны -2.315 и 2.273
# Критические значения распределения Стьюдента -- -2.8784404727135864 и 2.878440472713585
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.05, полученные моделированием, равны -1.8 и 1.771
# Критические значения распределения Стьюдента -- -2.10092204024096 и 2.10092204024096
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10 и a = 0.1, полученные моделированием, равны -1.549 и 1.533
# Критические значения распределения Стьюдента -- -1.734063606617536 и 1.7340636066175354
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.01, полученные моделированием, равны -2.236 и 2.247
# Критические значения распределения Стьюдента -- -2.7115576019130625 и 2.7115576019130625
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.05, полученные моделированием, равны -1.76 и 1.75
# Критические значения распределения Стьюдента -- -2.0243941645751367 и 2.024394164575136
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=20 и a = 0.1, полученные моделированием, равны -1.501 и 1.514
# Критические значения распределения Стьюдента -- -1.6859544576438146 и 1.685954457643814
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.01, полученные моделированием, равны -2.153 и 2.172
# Критические значения распределения Стьюдента -- -2.6269310948140245 и 2.626931094814024
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.05, полученные моделированием, равны -1.722 и 1.726
# Критические значения распределения Стьюдента -- -1.9844674544266925 и 1.984467454426692
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=50 и a = 0.1, полученные моделированием, равны -1.519 и 1.495
# Критические значения распределения Стьюдента -- -1.6605512170440575 и 1.6605512170440568
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.01, полученные моделированием, равны -2.176 и 2.154
# Критические значения распределения Стьюдента -- -2.600887277962623 и 2.6008872779626224
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.05, полученные моделированием, равны -1.731 и 1.714
# Критические значения распределения Стьюдента -- -1.972017477833896 и 1.9720174778338955
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=100 и a = 0.1, полученные моделированием, равны -1.512 и 1.505
# Критические значения распределения Стьюдента -- -1.6525857836172082 и 1.6525857836172075
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.01, полученные моделированием, равны -2.151 и 2.154
# Критические значения распределения Стьюдента -- -2.5807645863853454 и 2.580764586385345
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.05, полученные моделированием, равны -1.696 и 1.719
# Критические значения распределения Стьюдента -- -1.962343846216334 и 1.9623438462163336
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=500 и a = 0.1, полученные моделированием, равны -1.484 и 1.508
# Критические значения распределения Стьюдента -- -1.6463818766348761 и 1.6463818766348755
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.01, полученные моделированием, равны -2.191 и 2.142
# Критические значения распределения Стьюдента -- -2.57607517760687 и 2.5760751776068695
# Критические значения стандартного нормального распределения -- -2.575829303548901 и 2.5758293035489004
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.05, полученные моделированием, равны -1.725 и 1.717
# Критические значения распределения Стьюдента -- -1.960082617022089 и 1.9600826170220886
# Критические значения стандартного нормального распределения -- -1.9599639845400545 и 1.959963984540054
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Критические значения для статистики при n=10000 и a = 0.1, полученные моделированием, равны -1.522 и 1.486
# Критические значения распределения Стьюдента -- -1.6449298265798 и 1.6449298265797994
# Критические значения стандартного нормального распределения -- -1.6448536269514729 и 1.6448536269514722
# ------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Как видим, тут уже отклонения от квантилей достаточно большие.
